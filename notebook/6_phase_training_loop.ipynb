# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(
    str(PROJECT_ROOT)
)

# %%
import torch

from src.models.yolo11_fod import YOLO11FOD

# %% [markdown]
# ## **Training Configuration :**

# %%
from src.training.config import load_config

# %%
config = load_config(
    "../src/configs/train_config.yaml"
)

# %%
print(config)
# Out:
# {'model': {'num_classes': 10, 'reg_max': 16, 'image_size': 640}, 'training': {'epochs': 50, 'batch_size': 8, 'num_workers': 4, 'seed': 42, 'device': 'cuda', 'amp': True, 'gradient_clip': 10.0}, 'optimizer': {'name': 'AdamW', 'learning_rate': 0.001, 'weight_decay': 0.0005, 'momentum': 0.937}, 'scheduler': {'name': 'cosine', 'min_lr': 1e-05, 'warmup_epochs': 3}, 'loss': {'box_weight': 7.5, 'cls_weight': 0.5, 'dfl_weight': 1.5}, 'checkpoint': {'save_dir': 'checkpoints', 'save_best': True, 'save_last': True}, 'logging': {'print_frequency': 20, 'save_history': True}}

# %%
print(
    "Epochs:",
    config["training"]["epochs"]
)

print(
    "Batch size:",
    config["training"]["batch_size"]
)

print(
    "Learning rate:",
    config["optimizer"]["learning_rate"]
)

print(
    "Optimizer:",
    config["optimizer"]["name"]
)
# Out:
# Epochs: 50
# Batch size: 8
# Learning rate: 0.001
# Optimizer: AdamW

# %% [markdown]
# ##  **Optimizer :**

# %%
from src.models.yolo11_fod import YOLO11FOD
from src.training.optimizer import build_optimizer

# %%
model = YOLO11FOD(
    num_classes=10,
    reg_max=16
)

# %%
optimizer = build_optimizer(
    model,
    config
)

# %%
print(optimizer)
# Out:
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0.0005
# )

# %% [markdown]
# ## **Learning Rate Scheduler :**

# %%
from src.training.scheduler import build_scheduler

# %%
scheduler = build_scheduler(
    optimizer,
    config
)

# %%
print(scheduler)
# Out:
# <torch.optim.lr_scheduler.CosineAnnealingLR object at 0x000001D9A6638580>
